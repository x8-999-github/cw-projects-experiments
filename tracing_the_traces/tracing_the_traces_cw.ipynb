# %% [markdown]
# # ChipwWhisperer solution for tracing the traces

# %% [markdown]
# First looking at overview.png We see that what we see looks like a trace followed by a period of inacivity. We also see some repetitions in the traces (experts will tell you those are probably AES rounds and given the count 9 + a special one) we might be talking AES128
#
# ![trace overview](overview.png)

# %% [markdown]
# We tried opening the file in scipy , but this failed.

# %%
import scipy.io as sio
sio.loadmat("traces.mat")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-3c4d7a7f5665> in <module>()
#       1 import scipy.io as sio
# ----> 2 sio.loadmat("traces.mat")
#
# /usr/lib/python2.7/dist-packages/scipy/io/matlab/mio.pyc in loadmat(file_name, mdict, appendmat, **kwargs)
#     132     """
#     133     variable_names = kwargs.pop('variable_names', None)
# --> 134     MR = mat_reader_factory(file_name, appendmat, **kwargs)
#     135     matfile_dict = MR.get_variables(variable_names)
#     136     if mdict is not None:
#
# /usr/lib/python2.7/dist-packages/scipy/io/matlab/mio.pyc in mat_reader_factory(file_name, appendmat, **kwargs)
#      56     """
#      57     byte_stream = _open_file(file_name, appendmat)
# ---> 58     mjv, mnv = get_matfile_version(byte_stream)
#      59     if mjv == 0:
#      60         return MatFile4Reader(byte_stream, **kwargs)
#
# ...

# %% [markdown]
# We tried reading the .mat file using scipy but that failed. we therefore opened it in octave seeing that we have 300 traces, (32 bytes in out , so probably 16 bytes in and 16 bytes out) and 6095 trace points
#
# ![open trace file in octave](pics/open_in_octave.png)

# %% [markdown]
# After some more research we figured out it was possible to convert the mat file to an older version and read it with scipy. We use octave to do this

# %%
import subprocess

subprocess.call(["octave-cli","--eval",'load "traces.mat" ; save -6 "traces_6.mat"'])
traces  = sio.loadmat("traces_6.mat")
traces
# Out:
# {'__globals__': [],
#  '__header__': 'MATLAB 5.0 MAT-file, written by Octave 4.0.0, 2017-08-31 07:58:49 UTC',
#  '__version__': '1.0',
#  'inout': array([[  42,  -63,   24, ...,   79,   -6,  -91],
#         [ -31,  -56,  112, ..., -102,  -16,    7],
#         [  33,   76, -110, ...,   44,    1,   21],
#         ...,
#         [ 112,  -96,   51, ...,  -20, -107,  -52],
#         [-119,  -14,  -37, ...,  -47,   22,   95],
#         [  99,  -96,  -19, ...,   26,  -37,  -90]], dtype=int8),
#  'samples': array([[ 33.33333206,  30.        ,  35.875     , ...,  10.5       ,
#            7.125     ,   0.        ],
#         [ 15.11111069,  30.625     ,  31.75      , ...,  18.5       ,
#           15.5       ,   0.        ],
#         [ 34.66666794,  42.25      ,  43.5       , ...,  34.125     ,
#           31.125     ,   0.        ],
#         ...,
#         [-13.22222233, -68.125     , -69.5       , ...,  17.5       ,
#           15.75      ,   0.        ],
# ...

# %% [markdown]
# # Plot the data
#
# Next we tried plotting the data

# %%
#add magic
# %matplotlib inline

# and plot the  data
import numpy as np
import matplotlib.pyplot as plt

plt.plot(traces['samples'][0])
plt.plot(traces['samples'][1])
plt.plot(traces['samples'][2])
plt.show()

# %% [markdown]
# When comparing the trace above with the given overview we "see" that the trace operates at the start of the overview so probably this
# is a trace at the start of an encrytion.
# ![](overview.png)

# %% [markdown]
# Next I messed around converting the trace files to CW format

# %%
traceCount = len(traces['samples'])
traceLen = len(traces['samples'][0])


textins = np.zeros([traceCount, 16], dtype=np.uint8)
for n in range(0,traceCount):
    textins[n] = map(int,traces['inout'][n][:16])
    
textouts = np.zeros([traceCount, 16], dtype=np.uint8)
for n in range(0,traceCount):
    textouts[n] = map(int,traces['inout'][n][16:])
    
traces_cw = np.array(traces['samples'], dtype=np.float)

prefix="test"
np.save("%straces.npy" % prefix,traces_cw)
np.save("%stextin.npy" % prefix,textins)
np.save("%stextout.npy" % prefix,textouts)

# %%
# new script base on https://forum.newae.com/viewtopic.php?f=9&t=362
import scipy.io as sio
import numpy as np
import ctypes
import os
import subprocess
from chipwhisperer.common.traces.TraceContainerNative import TraceContainerNative

#convert the traces to version 6
subprocess.call(["octave-cli","--eval",'load "traces.mat" ; save -6 "traces_6.mat"'])
traces = sio.loadmat("traces_6.mat")

ntraces = len(traces['samples'])
traceLen = len(traces['samples'][0])


inp = np.uint8(traces['inout'][:, 0:16])
out = np.uint8(traces['inout'][:, 16:32])

#If you'd like to plot a trace to see it
import matplotlib.pyplot as plt
plt.plot(traces['samples'][0,:], 'r')
plt.plot(traces['samples'][1,:], 'b')
plt.show()

#Save as ChipWhisperer project
tc = TraceContainerNative()
for i in range(0, ntraces):
    tc.addWave(traces['samples'][i])
    tc.addTextin(inp[i])
    tc.addTextout(out[i])

    #Temp - add fake key info. Required on Linux possibly, will be fixed to avoid this. Be sure to turn
    #highlight key off to avoid being confused.
    tc.addKey([0]*16)

os.mkdir('rhme3')
tc.saveAllTraces('rhme3')
tc.config.setConfigFilename('rhme3/rhme.cfg')
tc.config.saveTrace()

# %% [markdown]
# As documented by coflynn you needed to edit the rhme.cfg to remove the prefix from "None" to empty

# %% [markdown]
# Next start CW-ana and load the trace using the trace manager and select that you want a sum of abstolute difference filter and play around with the settings until the thing works. I notices that when playing with the SAD filter the input window must be quite large compared to the reference points (else you get an exception)
#
# ![](pics/win.png)
